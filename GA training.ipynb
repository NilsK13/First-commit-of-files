# %%
t0 = 1126259462.4

detector = 'H1'

# %%
import requests, os
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

try:
    from gwpy.timeseries import TimeSeries
except:
    ! pip install -q "gwpy==3.0.9"
    ! pip install -q "matplotlib==3.7.3"
    ! pip install -q "astropy==6.1.4"
    from gwpy.timeseries import TimeSeries

plt.ion()

# %%
center = int(t0)
strain = TimeSeries.fetch_open_data(detector, center-16, center+16)

# %%
fig1 = strain.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 fig1 = strain.plot()
#
# File c:\Users\nka0613\AppData\Local\anaconda3\Lib\site-packages\gwpy\timeseries\core.py:621, in TimeSeriesBase.plot(self, method, figsize, xscale, **kwargs)
#     602 """Plot the data for this timeseries
#     603
#     604 Returns
#    (...)
#     618     for documentation of keyword arguments used in rendering the data
#     619 """
#     620 kwargs.update(figsize=figsize, xscale=xscale)
# --> 621 return super().plot(method=method, **kwargs)
#
# File c:\Users\nka0613\AppData\Local\anaconda3\Lib\site-packages\gwpy\types\series.py:468, in Series.plot(self, method, **kwargs)
#     465     kwargs.setdefault('xlim', (self.dx.value, self.xspan[1]))
#     467 # make plot
# --> 468 plot = Plot(self, method=method, **kwargs)
#     470 # set default y-axis label (xlabel is set by Plot())
#     471 default_unit_label(plot.gca().yaxis, self.unit)
#
# File c:\Users\nka0613\AppData\Local\anaconda3\Lib\site-packages\gwpy\plot\plot.py:112, in Plot.__init__(self, *data, **kwargs)
#     109 # initialise figure
#     110 figure_kw = {key: kwargs.pop(key) for key in utils.FIGURE_PARAMS if
#     111              key in kwargs}
# --> 112 self._init_figure(**figure_kw)
#     114 # initialise axes with data
#     115 if data or kwargs.get("geometry"):
#
# File c:\Users\nka0613\AppData\Local\anaconda3\Lib\site-packages\gwpy\plot\plot.py:132, in Plot._init_figure(self, **kwargs)
#     129 self.number = num
#     131 # add interactivity (scraped from pyplot.figure())
# --> 132 backend_mod = get_backend_mod()
#     133 try:
#     134     manager = backend_mod.new_figure_manager_given_figure(num, self)
#
# File c:\Users\nka0613\AppData\Local\anaconda3\Lib\site-packages\gwpy\plot\plot.py:85, in get_backend_mod(name)
#      80     name = get_backend()
#      81 backend_name = (
#      82     name[9:] if name.startswith("module://")
#      83     else f"matplotlib.backends.backend_{name.lower()}"
#      84 )
# ---> 85 return importlib.import_module(backend_name)
#
# File c:\Users\nka0613\AppData\Local\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'matplotlib.backends.backend_inline'
