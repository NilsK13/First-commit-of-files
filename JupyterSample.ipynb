# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %%
array1 = np.arange(0,6,0.1)

# %%
x = array1
y = x**2

# %%
plt.plot(x,y)
plt.show()
